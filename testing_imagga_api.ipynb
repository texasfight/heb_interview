# %%
import requests

# %%
import requests

api_key = 'acc_d7384deaa250aff'
api_secret = '484468850f8f4e638605f74bbcdada88'
image_path = r'C:\Users\irvin\PycharmProjects\heb_interview\marissa-lewis-PoL7eR-p4Z0-unsplash.jpg'

response = requests.post(
    'https://api.imagga.com/v2/tags',
    auth=(api_key, api_secret),
    files={'image': open(image_path, 'rb')})
print(response.json())
# Out:
# {'result': {'tags': [{'confidence': 100, 'tag': {'en': 'monitor'}}, {'confidence': 89.6708374023438, 'tag': {'en': 'computer'}}, {'confidence': 76.8778533935547, 'tag': {'en': 'keyboard'}}, {'confidence': 56.3951568603516, 'tag': {'en': 'screen'}}, {'confidence': 50.5814781188965, 'tag': {'en': 'desktop computer'}}, {'confidence': 50.5244445800781, 'tag': {'en': 'technology'}}, {'confidence': 46.2664680480957, 'tag': {'en': 'laptop'}}, {'confidence': 44.8651885986328, 'tag': {'en': 'personal computer'}}, {'confidence': 44.4428672790527, 'tag': {'en': 'office'}}, {'confidence': 43.7732734680176, 'tag': {'en': 'business'}}, {'confidence': 40.3566932678223, 'tag': {'en': 'display'}}, {'confidence': 39.8189697265625, 'tag': {'en': 'mouse'}}, {'confidence': 39.456729888916, 'tag': {'en': 'desk'}}, {'confidence': 37.719612121582, 'tag': {'en': 'work'}}, {'confidence': 33.252197265625, 'tag': {'en': 'digital computer'}}, {'confidence': 32.8048553466797, 'tag': {'en': 'notebook'}}, {'confide
# ...

# %%
import pprint

# %%
pprint.pprint(response.json())
# Out:
# {'result': {'tags': [{'confidence': 100, 'tag': {'en': 'monitor'}},
#                      {'confidence': 89.6708374023438,
#                       'tag': {'en': 'computer'}},
#                      {'confidence': 76.8778533935547,
#                       'tag': {'en': 'keyboard'}},
#                      {'confidence': 56.3951568603516, 'tag': {'en': 'screen'}},
#                      {'confidence': 50.5814781188965,
#                       'tag': {'en': 'desktop computer'}},
#                      {'confidence': 50.5244445800781,
#                       'tag': {'en': 'technology'}},
#                      {'confidence': 46.2664680480957, 'tag': {'en': 'laptop'}},
#                      {'confidence': 44.8651885986328,
#                       'tag': {'en': 'personal computer'}},
#                      {'confidence': 44.4428672790527, 'tag': {'en': 'office'}},
#                      {'confidence': 43.7732734680176,
#                       'tag': {'en': 'business'}},
# ...

# %%
response2 = requests.get(
    'https://api.imagga.com/v2/tags?image_url=%s' % "https://images.unsplash.com/photo-1677022725616-91e41d36db21?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=687&q=80",
    auth=(api_key, api_secret))

pprint.pprint(response2.json())
# Out:
# {'result': {'tags': [{'confidence': 100, 'tag': {'en': 'monitor'}},
#                      {'confidence': 89.4431991577148,
#                       'tag': {'en': 'computer'}},
#                      {'confidence': 76.8799896240234,
#                       'tag': {'en': 'keyboard'}},
#                      {'confidence': 56.4520721435547, 'tag': {'en': 'screen'}},
#                      {'confidence': 50.5249633789062,
#                       'tag': {'en': 'technology'}},
#                      {'confidence': 49.9497261047363,
#                       'tag': {'en': 'desktop computer'}},
#                      {'confidence': 46.2284660339355, 'tag': {'en': 'laptop'}},
#                      {'confidence': 44.4878196716309, 'tag': {'en': 'office'}},
#                      {'confidence': 44.2726249694824,
#                       'tag': {'en': 'personal computer'}},
#                      {'confidence': 43.7737426757812,
#                       'tag': {'en': 'business'}},
# ...
